# %% [markdown]
# # **Exploring Factors of Problematic Internet Use in Children**

# %% [markdown]
# In today's digital age, problematic internet use among children and adolescents is a growing concern, often linked to mental health issues like depression and anxiety. Current methods for measuring problematic internet use are complex and require professional assessments, creating barriers for many families.
#
# Physical fitness indicators, such as posture, diet, and activity levels, are more accessible and can serve as proxies for detecting problematic internet use. Changes in these habits are commonly observed in excessive technology users.
#
# This competition challenges us to develop a predictive model using children's physical activity data to detect early signs of problematic internet use, enabling timely interventions and promoting healthier digital habits.Our work will help children navigate the digital landscape responsibly and lead healthier lives.

# %% [markdown]
# #  **Importing important liabraries**

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
import numpy as np
import seaborn as sns
#from ydata_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
import warnings
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
#from sklearn.preprocessing import FunctionTransformer
import dask.dataframe as dd
import polars as pl
from pathlib import Path
from tqdm import tqdm
import pyarrow as pa
import pyarrow.parquet as pq
from scipy import stats
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import cohen_kappa_score
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Loading the train, test and submission csv**

# %%
submission= pd.read_csv("/content/drive/MyDrive/comptetion/child-mind-institute-problematic-internet-use/sample_submission.csv")
submission.head(2)
# Out:
#          id  prediction
# 0  00008ff9         2.0
# 1  000fd460         0.0

# %%
X_test = pd.read_csv('/content/drive/MyDrive/comptetion/child-mind-institute-problematic-internet-use/test.csv')
print(X_test.head(2))
print(X_test.shape)
print(X_test.columns)
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
#
#    Physical-HeartRate  Physical-Systolic_BP Fitness_Endurance-Season  \
# 0                 NaN                   NaN                      NaN
# 1                70.0                 122.0                      NaN
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN       Fall         0.0              0.0
# 1                         NaN       Fall         3.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone BIA-Season  \
# 0               0.0         6.0              1.0       Fall
# 1               1.0         3.0              0.0     Winter
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
#
#    BIA-BIA_SMM  BIA-BIA_TBW PAQ_A-Season  PAQ_A-PAQ_A_Total PAQ_C-Season  \
# 0      19.5413      32.6909          NaN                NaN          NaN
# 1      15.4107      27.0552          NaN                NaN         Fall
#
#    PAQ_C-PAQ_C_Total SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN        NaN                NaN              NaN
# 1               2.34       Fall               46.0             64.0
#
#   PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday
# 0                Fall                                     3.0
# 1              Summer                                     0.0
# (20, 59)
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
#        'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday'],
#       dtype='object')

# %%
missing_values = X_test.isnull().sum()

# %%
X_test.describe().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_71eec_row0_col0, #T_71eec_row0_col1, #T_71eec_row0_col14, #T_71eec_row0_col16, #T_71eec_row0_col18, #T_71eec_row0_col20, #T_71eec_row0_col21, #T_71eec_row0_col22, #T_71eec_row0_col24, #T_71eec_row0_col25, #T_71eec_row0_col26, #T_71eec_row0_col27, #T_71eec_row0_col28, #T_71eec_row0_col37, #T_71eec_row0_col44, #T_71eec_row0_col47, #T_71eec_row1_col43, #T_71eec_row3_col43, #T_71eec_row4_col43, #T_71eec_row5_col43, #T_71eec_row6_col43, #T_71eec_row7_col2, #T_71eec_row7_col3, #T_71eec_row7_col4, #T_71eec_row7_col5, #T_71eec_row7_col6, #T_71eec_row7_col7, #T_71eec_row7_col8, #T_71eec_row7_col9, #T_71eec_row7_col10, #T_71eec_row7_col11, #T_71eec_row7_col12, #T_71eec_row7_col13, #T_71eec_row7_col15, #T_71eec_row7_col17, #T_71eec_row7_col19, #T_71eec_row7_col23, #T_71eec_row7_col29, #T_71eec_row7_col30, #T_71eec_row7_col31, #T_71eec_row7_col32, #T_71eec_row7_col33, #T_71eec_row7_col34, #T_71eec_row7_col35, #T_71eec_row7_col36, #T_71eec_row7_col38, #T_71eec_row7_col39, #T_71eec_row7_col40, #T_71eec_row7_col41, #T_71eec_row7_col42, #T_71eec_row7_col43, #T_71eec_row7_col45, #T_71eec_row7_col46 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T
{
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_71eec_row1_col12 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_71eec_row1_col13, #T_71eec_row3_col3, #T_71eec_row3_col29 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col14, #T_71eec_row2_col24, #T_71eec_row2_col26 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col15 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col17, #T_71eec_row5_col33 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_71eec_row1_col19 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col20, #T_71eec_row2_col25 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col21, #T_71eec_row3_col4 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col22, #T_71eec_row2_col14, #T_71eec_row2_col22 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col23, #T_71eec_row3_col45, #T_71eec_row4_col42, #T_71eec_row5_col3 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col24, #T_71eec_row6_col1, #T_71eec_row7_col1 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col25 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col27 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col28, #T_71eec_row5_col0 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col29, #T_71eec_row7_col27 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col30 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_71eec_row1_col31, #T_71eec_row5_col23 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col33, #T_71eec_row3_col8 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col34, #T_71eec_row3_col12, #T_71eec_row6_col46 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_71eec_row1_col35, #T_71eec_row2_col23 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col36, #T_71eec_row6_col27 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col37 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col39 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col40 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col41, #T_71eec_row6_col3 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_71eec_row1_col42 {
#   background-color: #38b977;
#   color: #f1f1

# %%
X_train= pd.read_csv('/content/drive/MyDrive/comptetion/child-mind-institute-problematic-internet-use/train.csv')
X_train.head(2)
print(X_train.shape)
print(X_train.columns)
# Out:
# (3960, 82)
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'PCIAT-Season', 'PCIAT-PCIAT_01', 'PCIAT-PCIAT_02',
#        'PCIAT-PCIAT_03', 'PCIAT-PCIAT_04', 'PCIAT-PCIAT_05', 'PCIAT-PCIAT_06',
#        'PCIAT-PCIAT_07', 'PCIAT-PCIAT_08', 'PCIAT-PCIAT_09', 'PCIAT-PCIAT_10',
#        'PCIAT-PCIAT_11', 'PCIAT-PCIAT_12', 'PCIAT-PCIAT_13', 'PCIAT-PCIAT_14',
#        'PCIAT-PCIAT_15', 'PCIAT-PCIAT_16', 'PCIAT-PCIAT_17', 'PCIAT-PCIAT_18',
#        'PCIAT-PCIAT_19', 'PCIAT-PCIAT_20', 'PCIAT-PCIAT_Total', 'SDS-Season',
#        'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday', 'sii'],
#       dtype='object')

# %% [markdown]
# **Since the "SII" family is drawn by the PICAT family, I am excluding all family-related features associated with PICAT from the training dataset. This adjustment is also made to ensure consistency with the provided test.csv file.**

# %%
 X_train= X_train.drop(
    columns=[
        'PCIAT-Season', 'PCIAT-PCIAT_01', 'PCIAT-PCIAT_02', 'PCIAT-PCIAT_03',
        'PCIAT-PCIAT_04', 'PCIAT-PCIAT_05', 'PCIAT-PCIAT_06', 'PCIAT-PCIAT_07',
        'PCIAT-PCIAT_08', 'PCIAT-PCIAT_09', 'PCIAT-PCIAT_10', 'PCIAT-PCIAT_11',
        'PCIAT-PCIAT_12', 'PCIAT-PCIAT_13', 'PCIAT-PCIAT_14', 'PCIAT-PCIAT_15',
        'PCIAT-PCIAT_16', 'PCIAT-PCIAT_17', 'PCIAT-PCIAT_18', 'PCIAT-PCIAT_19',
        'PCIAT-PCIAT_20', 'PCIAT-PCIAT_Total'
    ]
 )

X_train.shape
# Out:
# (3960, 60)

# %%
X_train.columns
# Out:
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
#        'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
#        'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
#        'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
#        'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
#        'PreInt_EduHx-computerinternet_hoursday', 'sii'],
#       dtype='object')

# %%
missing_values = X_train.isnull().sum()

missing_values
# Out:
# id                                           0
# Basic_Demos-Enroll_Season                    0
# Basic_Demos-Age                              0
# Basic_Demos-Sex                              0
# CGAS-Season                               1405
# CGAS-CGAS_Score                           1539
# Physical-Season                            650
# Physical-BMI                               938
# Physical-Height                            933
# Physical-Weight                            884
# Physical-Waist_Circumference              3062
# Physical-Diastolic_BP                     1006
# Physical-HeartRate                         993
# Physical-Systolic_BP                      1006
# Fitness_Endurance-Season                  2652
# Fitness_Endurance-Max_Stage               3217
# Fitness_Endurance-Time_Mins               3220
# Fitness_Endurance-Time_Sec                3220
# FGC-Season                                 614
# FGC-FGC_CU                                1638
# FGC-FGC_CU_Zone                           1678
# FGC-FGC_GSND                              2886
# FGC-FGC_GSND_Zone                         2898
# FGC-FGC_GSD                               2886
# FGC-FGC_GSD_Zone                          2897
# FGC-FGC_PU                                1650
# FGC-FGC_PU_Zone                           1689
# FGC-FGC_SRL                               1655
# FGC-FGC_SRL_Zone                          1693
# FGC-FGC_SRR                               1653
# FGC-FGC_SRR_Zone                          1691
# FGC-FGC_TL                                1636
# FGC-FGC_TL_Zone                           1675
# BIA-Season                                1815
# BIA-BIA_Activity_Level_num                1969
# BIA-BIA_BMC                               1969
# BIA-BIA_BMI                               1969
# BIA-BIA_BMR                               1969
# BIA-BIA_DEE                               1969
# BIA-BIA_ECW                               1969
# BIA-BIA_FFM                               1969
# BIA-BIA_FFMI                              1969
# BIA-BIA_FMI                               1969
# BIA-BIA_Fat                               1969
# BIA-BIA_Frame_num                         1969
# BIA-BIA_ICW                               1969
# BIA-BIA_LDM                               1969
# BIA-BIA_LST                               1969
# BIA-BIA_SMM                               1969
# BIA-BIA_TBW                               1969
# PAQ_A-Season                              3485
# PAQ_A-PAQ_A_Total                         3485
# PAQ_C-Season                              2239
# PAQ_C-PAQ_C_Total                         2239
# SDS-Season                                1342
# SDS-SDS_Total_Raw                         1351
# SDS-SDS_Total_T                           1354
# PreInt_EduHx-Season                        420
# PreInt_EduHx-computerinternet_hoursday     659
# sii                                       1224
# dtype: int64

# %%
X_train.describe().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
#T_892df_row6_col16, #T_892df_row6_col18, #T_892df_row6_col19, #T_892df_row6_col20, #T_892df_row6_col22, #T_892df_row6_col24, #T_892df_row6_col26, #T_892df_row6_col27, #T_892df_row6_col28, #T_892df_row6_col37, #T_892df_row6_col44, #T_892df_row6_col47, #T_892df_row6_col48, #T_892df_row7_col1, #T_892df_row7_col14, #T_892df_row7_col16, #T_892df_row7_col18, #T_892df_row7_col20, #T_892df_row7_col22, #T_892df_row7_col24, #T_892df_row7_col26, #T_892df_row7_col27, #T_892df_row7_col37, #T_892df_row7_col44, #T_892df_row7_col47, #T_892df_row7_col48 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_892df_row1_col2, #T_892df_row1_col4, #T_892df_row1_col46, #T_892df_row2_col33, #T_892df_row2_col38, #T_892df_row2_col40, #T_892df_row2_col42, #T_892df_row4_col5, #T_892df_row4_col12, #T_892df_row5_col2, #T_892df_row5_col4, #T_892df_row5_col15, #T_892df_row5_col46, #T_892df_row6_col4 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_892df_row1_col5, #T_892df_row6_col6 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_892df_row1_col6, #T_892df_row1_col7, #T_892df_row2_col12, #T_892df_row2_col28, #T_892df_row5_col5, #T_892df_row6_col7, #T_892df_row6_col8, #T_892df_row6_col15, #T_892df_row6_col17, #T_892df_row7_col4, #T_892df_row7_col11, #T_892df_row7_col29 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_892df_row1_col8, #T_892df_row1_col15, #T_892df_row1_col17, #T_892df_row2_col32, #T_892df_row2_col39, #T_892df_row2_col41, #T_892df_row4_col6, #T_892df_row4_col7, #T_892df_row4_col8, #T_892df_row5_col6, #T_892df_row5_col7, #T_892df_row5_col8, #T_892df_row5_col17, #T_892df_row6_col2, #T_892df_row6_col46, #T_892df_row7_col3, #T_892df_row7_col19 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_892df_row1_col9, #T_892df_row6_col9, #T_892df_row7_col8 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_892df_row1_col11, #T_892df_row1_col29, #T_892df_row1_col31, #T_892df_row1_col40, #T_892df_row1_col41, #T_892df_row2_col15, #T_892df_row2_c

# %%
X= X_train.drop(columns=['sii','id'])
y= X_train['sii']

# %% [markdown]
#    **I am uploading the time series parquet file using Dask DataFrame and PyArrow for efficient handling of large datasets. After loading the data, I will merge the time series data with the main CSV file based on the ID column to ensure proper alignment of the datasets for further analysis.**

# %%
def get_ts_feature(id_path):

    df = pl.read_parquet(id_path / 'part-0.parquet')
    ts_feature = df.describe().filter(
        ~pl.col("statistic").is_in(["count", "null_count"])
    ).select(
        pl.all().exclude(["statistic", "step"])
    ).to_numpy().reshape(-1)


    patient_id = id_path.name.split("=")[1]

    return ts_feature, patient_id


def get_all_ts_feature(parquet_dir) -> pd.DataFrame:
    items = list(Path(parquet_dir).iterdir())
    features = []
    ids = []


    for id_path in tqdm(items):
        feature, patient_id = get_ts_feature(id_path)
        features.append(feature)
        ids.append(patient_id)


    columns = [f"stat_{i}" for i in range(len(features[0]))]
    df = pd.DataFrame(features, columns=columns, index=ids)

    return df

train_df = get_all_ts_feature("/content/drive/MyDrive/comptetion/child-mind-institute-problematic-internet-use/series_train.parquet")
print(train_df.head(1))

test_df = get_all_ts_feature("/content/drive/MyDrive/comptetion/child-mind-institute-problematic-internet-use/series_test.parquet")
# 00115b9f  5.500000e+10      1.0      3.0     41.0 -0.684193 -0.30987
#
#            stat_38   stat_39    stat_40  stat_41   stat_42      stat_43  \
# 00115b9f -0.649974  0.006431 -41.543835      0.0  2.392968  4028.666748
#
#                stat_44  stat_45  stat_46  stat_47   stat_48   stat_49  \
# 00115b9f  3.689000e+13      3.0      3.0     42.0 -0.366849  0.024974
#
#            stat_50   stat_51    stat_52  stat_53   stat_54  stat_55  \
# 00115b9f -0.245365  0.023638 -15.084804      0.0  6.926829   4070.0
#
#                stat_56  stat_57  stat_58  stat_59   stat_60   stat_61  \
# 00115b9f  5.348000e+13      5.0      3.0     50.0 -0.010677  0.400677
#
#           stat_62  stat_63    stat_64  stat_65  stat_66  stat_67  \
# 00115b9f  0.20474  0.04142  12.220962      0.0     15.0   4147.0
#
#                stat_68  stat_69  stat_70  stat_71   stat_72   stat_73  \
# 00115b9f  6.641000e+13      6.0      3.0     53.0  1.507865  1.666354
#
#            stat_74   stat_75    stat_76  stat_77  stat_78  stat_79  \
# 00115b9f  1.546979  4.004276  89.751656      0.0  2633.25   4188.5
#
#                stat_80  stat_81  stat_82  stat_83
# 00115b9f  8.611000e+13      7.0      3.0     85.0

# %%
#mege xtrain with train df

df_train = pd.merge(X_train, train_df, how='left', left_on='id', right_index=True)
df_test = pd.merge(X_test, test_df, how='left', left_on='id', right_index=True)
df_train.shape, df_test.shape
# Out:
# ((3960, 144), (20, 143))

# %%
df_train.head(1)
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
#
#    Physical-HeartRate  Physical-Systolic_BP Fitness_Endurance-Season  \
# 0                 NaN                   NaN                      NaN
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN       Fall         0.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone BIA-Season  \
# 0               0.0         6.0              1.0       Fall
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0       1492.0      8.25598      41.5862       13.8177      3.06143
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
#
#    BIA-BIA_SMM  BIA-BIA_TBW PAQ_A-Season  PAQ_A-PAQ_A_Total PAQ_C-Season  \
# 0      19.5413      32.6909          NaN                NaN          NaN
#
#    PAQ_C-PAQ_C_Total SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN        NaN                NaN              NaN
#
#   PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  sii  stat_0  \
# 0                Fall                                     3.0  2.0     NaN
#
#    stat_1  stat_2  stat_3  stat_4  stat_5  stat_6  stat_7  stat_8  stat_9  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    stat_10  stat_11  stat_12  stat_13  stat_14  stat_15  stat_16  stat_17  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_18  stat_19  stat_20  stat_21  stat_22  stat_23  stat_24  stat_25  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_26  stat_27  stat_28  stat_29  stat_30  stat_31  stat_32  stat_33  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_34  stat_35  stat_36  stat_37  stat_38  stat_39  stat_40  stat_41  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_42  stat_43  stat_44  stat_45  stat_46  stat_47  stat_48  stat_49  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_50  stat_51  stat_52  stat_53  stat_54  stat_55  stat_56  stat_57  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_58  stat_59  stat_60  stat_61  stat_62  stat_63  stat_64  stat_65  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_66  stat_67  stat_68  stat_69  stat_70  stat_71  stat_72  stat_73  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_74  stat_75  stat_76  stat_77  stat_78  stat_79  stat_80  stat_81  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_82  stat_83
# 0      NaN      NaN

# %%
df_train.columns
# Out:
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight',
#        ...
#        'stat_74', 'stat_75', 'stat_76', 'stat_77', 'stat_78', 'stat_79',
#        'stat_80', 'stat_81', 'stat_82', 'stat_83'],
#       dtype='object', length=144)

# %%
df_train.head(2)
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
#
#    Physical-HeartRate  Physical-Systolic_BP Fitness_Endurance-Season  \
# 0                 NaN                   NaN                      NaN
# 1                70.0                 122.0                      NaN
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN       Fall         0.0              0.0
# 1                         NaN       Fall         3.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone BIA-Season  \
# 0               0.0         6.0              1.0       Fall
# 1               1.0         3.0              0.0     Winter
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
#
#    BIA-BIA_SMM  BIA-BIA_TBW PAQ_A-Season  PAQ_A-PAQ_A_Total PAQ_C-Season  \
# 0      19.5413      32.6909          NaN                NaN          NaN
# 1      15.4107      27.0552          NaN                NaN         Fall
#
#    PAQ_C-PAQ_C_Total SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN        NaN                NaN              NaN
# 1               2.34       Fall               46.0             64.0
#
#   PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  sii  stat_0  \
# 0                Fall                                     3.0  2.0     NaN
# 1              Summer                                     0.0  0.0     NaN
#
#    stat_1  stat_2  stat_3  stat_4  stat_5  stat_6  stat_7  stat_8  stat_9  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    stat_10  stat_11  stat_12  stat_13  stat_14  stat_15  stat_16  stat_17  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_18  stat_19  stat_20  stat_21  stat_22  stat_23  stat_24  stat_25  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_26  stat_27  stat_28  stat_29  stat_30  stat_31  stat_32  stat_33  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_34  stat_35  stat_36  stat_37  stat_38  stat_39  stat_40  stat_41  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_42  stat_43  stat_44  stat_45  stat_46  stat_47  stat_48  stat_49  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_50  stat_51  stat_52  stat_53  stat_54  stat_55  stat_56  stat_57  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_58  stat_59  stat_60  stat_61  stat_62  stat_63  stat_64  stat_65  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_66  stat_67  stat_68  stat_69  stat_70  stat_71  stat_72  stat_73  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_74  stat_75  stat_76  stat_77  stat_78  stat_79  stat_80  stat_81  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_82  stat_83
# 0      NaN      NaN
# 1      NaN      NaN

# %%
df_test.head(2)
# Out:
#          id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0  00008ff9                      Fall                5                0
# 1  000fd460                    Summer                9                0
#
#   CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  Physical-Height  \
# 0      Winter             51.0            Fall     16.877316             46.0
# 1         NaN              NaN            Fall     14.035590             48.0
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
#
#    Physical-HeartRate  Physical-Systolic_BP Fitness_Endurance-Season  \
# 0                 NaN                   NaN                      NaN
# 1                70.0                 122.0                      NaN
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN       Fall         0.0              0.0
# 1                         NaN       Fall         3.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone BIA-Season  \
# 0               0.0         6.0              1.0       Fall
# 1               1.0         3.0              0.0     Winter
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
#
#    BIA-BIA_SMM  BIA-BIA_TBW PAQ_A-Season  PAQ_A-PAQ_A_Total PAQ_C-Season  \
# 0      19.5413      32.6909          NaN                NaN          NaN
# 1      15.4107      27.0552          NaN                NaN         Fall
#
#    PAQ_C-PAQ_C_Total SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN        NaN                NaN              NaN
# 1               2.34       Fall               46.0             64.0
#
#   PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  stat_0  stat_1  \
# 0                Fall                                     3.0     NaN     NaN
# 1              Summer                                     0.0     NaN     NaN
#
#    stat_2  stat_3  stat_4  stat_5  stat_6  stat_7  stat_8  stat_9  stat_10  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
#
#    stat_11  stat_12  stat_13  stat_14  stat_15  stat_16  stat_17  stat_18  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_19  stat_20  stat_21  stat_22  stat_23  stat_24  stat_25  stat_26  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_27  stat_28  stat_29  stat_30  stat_31  stat_32  stat_33  stat_34  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_35  stat_36  stat_37  stat_38  stat_39  stat_40  stat_41  stat_42  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_43  stat_44  stat_45  stat_46  stat_47  stat_48  stat_49  stat_50  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_51  stat_52  stat_53  stat_54  stat_55  stat_56  stat_57  stat_58  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_59  stat_60  stat_61  stat_62  stat_63  stat_64  stat_65  stat_66  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_67  stat_68  stat_69  stat_70  stat_71  stat_72  stat_73  stat_74  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_75  stat_76  stat_77  stat_78  stat_79  stat_80  stat_81  stat_82  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    stat_83
# 0      NaN
# 1      NaN

# %%
missing_values = df_train.isnull().sum()
missing_values
# Out:
# id                              0
# Basic_Demos-Enroll_Season       0
# Basic_Demos-Age                 0
# Basic_Demos-Sex                 0
# CGAS-Season                  1405
#                              ...
# stat_79                      2964
# stat_80                      2964
# stat_81                      2964
# stat_82                      2964
# stat_83                      2964
# Length: 144, dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.columns
# Out:
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight',
#        ...
#        'stat_74', 'stat_75', 'stat_76', 'stat_77', 'stat_78', 'stat_79',
#        'stat_80', 'stat_81', 'stat_82', 'stat_83'],
#       dtype='object', length=143)

# %%
y.isnull().sum()
# Out:
# 1224

# %%
X= df_train.drop(columns=['sii','id'])
y= df_train['sii']
df_test= df_test.drop(columns=['id'])

# %% [markdown]
#  **Separating the numerical and categorical columns based on their data types**

# %%
numerical_cols =  X.select_dtypes(include=['int', 'float']).columns
categorical_cols = X.select_dtypes(include=['object']).columns
print(numerical_cols)
print(len(numerical_cols))
print(categorical_cols)
print(len(categorical_cols))
# Out:
# Index(['Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        ...
#        'stat_74', 'stat_75', 'stat_76', 'stat_77', 'stat_78', 'stat_79',
#        'stat_80', 'stat_81', 'stat_82', 'stat_83'],
#       dtype='object', length=132)
# 132
# Index(['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season',
#        'Fitness_Endurance-Season', 'FGC-Season', 'BIA-Season', 'PAQ_A-Season',
#        'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season'],
#       dtype='object')
# 10

# %%
print(len(X.columns))
print(len(df_test.columns))
# Out:
# 142
# 142

# %% [markdown]
# **Missing values are handled based on the distribution from the X and df_test data. For numerical features with a normal distribution, the mean is used for imputation, while for skewed distributions, the median is preferred. For categorical variables, missing values are imputed with the mode, representing the most frequent category. These methods ensure that imputation aligns with the underlying data patterns, minimizing bias and preserving data integrity.**

# %%
def is_normal_distributed(data):
    if data.isnull().all():
        return False
    _, p_value = stats.shapiro(data.dropna())  # Shapiro-Wilk test for normality
    return p_value > 0.05  # If p-value > 0.05, data is considered normal

# Loop through numerical columns and fill missing values in both training and test data
for column in numerical_cols:
    if is_normal_distributed(X[column]):
        # Impute with the mean from the training data
        X[column] = X[column].fillna(X[column].mean())
        df_test[column] = df_test[column].fillna(X[column].mean())  # Use mean from training for test data
    else:
        # Impute with the median from the training data
        X[column] = X[column].fillna(X[column].median())
        df_test[column] = df_test[column].fillna(X[column].median())  # Use median from training for test data

# Loop through categorical columns and fill missing values in both training and test data
for column in categorical_cols:
    mode_value = X[column].mode()[0]  # Get the most frequent value from the training data
    X[column] = X[column].fillna(mode_value)  # Impute with mode in training data
    df_test[column] = df_test[column].fillna(mode_value)  # Impute with mode in test data

# %% [markdown]
# **The function removes outliers from both the training dataset (X) and the test dataset (df_test) using the Interquartile Range (IQR) method, replacing outlier values with NaN. It then imputes missing values by filling NaNs with the mean for normally distributed columns and the median for non-normally distributed columns. Columns that are entirely NaN after outlier removal are skipped from the imputation process.**

# %%
def remove_outliers_and_impute(X, df_test, numerical_cols):
    # Calculate IQR for outlier detection
    q1 = X[numerical_cols].quantile(0.25)
    q3 = X[numerical_cols].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr


    X[numerical_cols] = X[numerical_cols].mask((X[numerical_cols] < lower_bound) | (X[numerical_cols] > upper_bound), np.nan)
    df_test[numerical_cols] = df_test[numerical_cols].mask((df_test[numerical_cols] < lower_bound) | (df_test[numerical_cols] > upper_bound), np.nan)

    for column in numerical_cols:
        if X[column].isnull().all():
            continue
        if is_normal_distributed(X[column]):

            X[column].fillna(X[column].mean(), inplace=True)
            df_test[column].fillna(X[column].mean(), inplace=True)
        else:

            X[column].fillna(X[column].median(), inplace=True)
            df_test[column].fillna(X[column].median(), inplace=True)


numerical_cols = X.select_dtypes(include=[np.number]).columns.tolist()
remove_outliers_and_impute(X, df_test, numerical_cols)

# %%
X.columns
# Out:
# Index(['Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        ...
#        'stat_74', 'stat_75', 'stat_76', 'stat_77', 'stat_78', 'stat_79',
#        'stat_80', 'stat_81', 'stat_82', 'stat_83'],
#       dtype='object', length=142)

# %%
print(X.columns.shape)
print(df_test.columns.shape)
# Out:
# (142,)
# (142,)

# %% [markdown]
# **I performed feature engineering by applying Standard Scaling to all numerical columns to normalize the data. For columns with categorical values, I applied One-Hot Encoding to transform them into a suitable numerical format. Additionally, some columns were already in a label form and did not require any transformation, as they were naturally suitable for the model without further encoding.**

# %%
# Existing list of columns for standard scaling
standard_scaler = ['Physical-Diastolic_BP', 'BIA-BIA_BMI', 'FGC-FGC_GSND', 'Physical-Weight', 'FGC-FGC_CU',
                   'BIA-BIA_LDM', 'Fitness_Endurance-Time_Sec', 'Basic_Demos-Age', 'BIA-BIA_Fat',
                   'BIA-BIA_LST', 'Physical-HeartRate', 'BIA-BIA_DEE', 'BIA-BIA_FFMI', 'PAQ_A-PAQ_A_Total',
                   'FGC-FGC_SRR', 'FGC-FGC_PU', 'FGC-FGC_SRL', 'SDS-SDS_Total_T', 'Physical-Systolic_BP',
                   'BIA-BIA_SMM', 'Physical-Waist_Circumference', 'Fitness_Endurance-Time_Mins',
                   'Physical-Height', 'BIA-BIA_FMI', 'SDS-SDS_Total_Raw', 'PAQ_C-PAQ_C_Total',
                   'CGAS-CGAS_Score', 'BIA-BIA_ICW', 'BIA-BIA_TBW', 'BIA-BIA_FFM',
                   'Fitness_Endurance-Max_Stage', 'BIA-BIA_BMR', 'Physical-BMI', 'BIA-BIA_ECW',
                   'BIA-BIA_BMC', 'FGC-FGC_GSD', 'FGC-FGC_TL']


standard_scaler += [col for col in X.columns if col.startswith('stat')]
print(len(standard_scaler))
# Out:
# 121

# %%
one_hot_encoder = [
    'Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season',
    'Fitness_Endurance-Season', 'FGC-Season', 'BIA-Season', 'PAQ_A-Season',
    'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season'
]

passthrough = [
    'Basic_Demos-Sex', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone',
    'FGC-FGC_PU_Zone', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL_Zone',
    'BIA-BIA_Activity_Level_num', 'BIA-BIA_Frame_num', 'PreInt_EduHx-computerinternet_hoursday'
]

# %% [markdown]
# **I applied the ColumnTransformer to preprocess all the features using the preprocessor. The transformer applies different preprocessing steps based on the feature types: StandardScaler for numerical features, OneHotEncoder for categorical features, and the passthrough option for columns that do not require any transformation. After setting up the transformer, I applied the preprocessor to transform the dataset, ensuring that each feature is processed appropriately before feeding it into the model.**

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("standard_scaler", StandardScaler(), standard_scaler),
        ("onehot_encoder", OneHotEncoder(), one_hot_encoder),
        ("passthrough", "passthrough", passthrough)
    ]
)

# %%
preprocessor.fit(X)

X_transformed_train = preprocessor.transform(X)
X_transformed_test = preprocessor.transform(df_test)

# %%
X_transformed_known = X_transformed_train[y.notnull()]
y_known = y[y.notnull()]  # Known target values
X_transformed_missing = X_transformed_train[y.isnull()]

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_transformed_known, y_known)
y_missing_pred = knn.predict(X_transformed_missing)

y.loc[y.isnull()] = y_missing_pred

print("Missing values in completed target:", y.isnull().sum())
# Out:
# Missing values in completed target: 0

# %%
# target vale
y.value_counts()
# Out:
# sii
# 0.0    2395
# 1.0    1014
# 2.0     516
# 3.0      35
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed_train, y, test_size=0.2, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (3168, 172)
# X_test: (792, 172)
# y_train: (3168,)
# y_test: (792,)

# %% [markdown]
# **To address class imbalance in the dataset, I applied a combination of SMOTE (Synthetic Minority Over-sampling Technique) and Random Under Sampling using a pipeline. This pipeline first oversamples the minority class using SMOTE and then undersamples the majority class, resulting in a balanced dataset for training.**

# %%
smote = SMOTE(random_state=42)
rus = RandomUnderSampler(random_state=42)

pipeline = Pipeline(steps=[('smote', smote), ('rus', rus)])

X_resampled, y_resampled = pipeline.fit_resample(X_train, y_train)

# %% [markdown]
# **For prediction on the Child Mind Institute dataset, I applied three different classifiers: Gradient Boosting, LightGBM (LGBM), and CatBoost. Among these models, CatBoost achieved the highest performance, outperforming the other classifiers in terms of prediction accuracy, demonstrating its effectiveness for this particular task.**

# %%
param_dist = {
    'learning_rate': [0.01, 0.05],
    'n_estimators': [50, 100],
    'max_depth': [3, 5],
}
gbm = GradientBoostingClassifier()

random_search = RandomizedSearchCV(
    estimator=gbm,
    param_distributions=param_dist,
    n_iter=50,
    cv=3,
    scoring='accuracy',
    verbose=1,
    n_jobs=-1,
    random_state=42
)


random_search.fit(X_resampled, y_resampled)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# RandomizedSearchCV(cv=3, estimator=GradientBoostingClassifier(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.01, 0.05],
#                                         'max_depth': [3, 5],
#                                         'n_estimators': [50, 100]},
#                    random_state=42, scoring='accuracy', verbose=1)

# %%
y_pred=random_search.predict(X_test)

print(len(y_test))
print(len(y_pred))
# Out:
# 792
# 792

# %%
from sklearn.metrics import cohen_kappa_score
qwk = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Quadratic Weighted Kappa: {qwk}')
# Out:
# Quadratic Weighted Kappa: 0.4522163412902901

# %%
catboost_params = {
    'iterations': 1000,
    'learning_rate': 0.05,
    'depth': 7,
    'loss_function': 'MultiClass',
    'random_state': 42
}

catboost_model = CatBoostClassifier(**catboost_params)
catboost_model.fit(X_train, y_train, cat_features=[])

y_pred = catboost_model.predict(X_test)


from sklearn.metrics import cohen_kappa_score

qwk = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Quadratic Weighted Kappa: {qwk}')
# Out:
# 0:	learn: 1.3410596	total: 20.5ms	remaining: 20.5s
# 1:	learn: 1.3019073	total: 37.6ms	remaining: 18.8s
# 2:	learn: 1.2659071	total: 53.5ms	remaining: 17.8s
# 3:	learn: 1.2353060	total: 73.9ms	remaining: 18.4s
# 4:	learn: 1.2069750	total: 105ms	remaining: 21s
# 5:	learn: 1.1794842	total: 122ms	remaining: 20.2s
# 6:	learn: 1.1554934	total: 137ms	remaining: 19.5s
# 7:	learn: 1.1337015	total: 154ms	remaining: 19s
# 8:	learn: 1.1150404	total: 169ms	remaining: 18.6s
# 9:	learn: 1.0960913	total: 185ms	remaining: 18.4s
# 10:	learn: 1.0802770	total: 201ms	remaining: 18.1s
# 11:	learn: 1.0656081	total: 221ms	remaining: 18.2s
# 12:	learn: 1.0519480	total: 238ms	remaining: 18.1s
# 13:	learn: 1.0392676	total: 254ms	remaining: 17.9s
# 14:	learn: 1.0256394	total: 270ms	remaining: 17.7s
# 15:	learn: 1.0140714	total: 287ms	remaining: 17.6s
# 16:	learn: 1.0031113	total: 303ms	remaining: 17.5s
# 17:	learn: 0.9924784	total: 319ms	remaining: 17.4s
# 967:	learn: 0.3080821	total: 21.4s	remaining: 706ms
# 968:	learn: 0.3077695	total: 21.4s	remaining: 684ms
# 969:	learn: 0.3074690	total: 21.4s	remaining: 662ms
# 970:	learn: 0.3073072	total: 21.4s	remaining: 640ms
# 971:	learn: 0.3070408	total: 21.4s	remaining: 618ms
# 972:	learn: 0.3068329	total: 21.5s	remaining: 595ms
# 973:	learn: 0.3065337	total: 21.5s	remaining: 573ms
# 974:	learn: 0.3063729	total: 21.5s	remaining: 551ms
# 975:	learn: 0.3061745	total: 21.5s	remaining: 529ms
# 976:	learn: 0.3059659	total: 21.5s	remaining: 507ms
# 977:	learn: 0.3058570	total: 21.5s	remaining: 485ms
# 978:	learn: 0.3057939	total: 21.6s	remaining: 463ms
# 979:	learn: 0.3056571	total: 21.6s	remaining: 440ms
# 980:	learn: 0.3055192	total: 21.6s	remaining: 418ms
# 981:	learn: 0.3053608	total: 21.6s	remaining: 396ms
# 982:	learn: 0.3050536	total: 21.6s	remaining: 374ms
# 983:	learn: 0.3047360	total: 21.6s	remaining: 352ms
# 984:	learn: 0.3044640	total: 21.7s	remaining: 330ms
# 985:	learn: 0.3042790	total: 21.7s	remaining: 308ms
# 986:	learn: 0.3040412	total: 21.7s	remaining: 286ms
# 987:	learn: 0.3038429	total: 21.7s	remaining: 264ms
# 988:	learn: 0.3034755	total: 21.7s	remaining: 242ms
# 989:	learn: 0.3033019	total: 21.7s	remaining: 220ms
# 990:	learn: 0.3030103	total: 21.8s	remaining: 198ms
# 991:	learn: 0.3027637	total: 21.8s	remaining: 176ms
# 992:	learn: 0.3024863	total: 21.8s	remaining: 154ms
# 993:	learn: 0.3022053	total: 21.8s	remaining: 132ms
# 994:	learn: 0.3019116	total: 21.9s	remaining: 110ms
# 995:	learn: 0.3017577	total: 21.9s	remaining: 88ms
# 996:	learn: 0.3014599	total: 21.9s	remaining: 66ms
# 997:	learn: 0.3011980	total: 22s	remaining: 44ms
# 998:	learn: 0.3010027	total: 22s	remaining: 22ms
# 999:	learn: 0.3009387	total: 22s	remaining: 0us
# Quadratic Weighted Kappa: 0.4935072070917049

# %%
y_pred = catboost_model.predict(X_transformed_test)

# %%
y_pred.shape
# Out:
# (20, 1)

# %% [markdown]
# **Final submission file:**

# %%
submission = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv')

submission = pd.DataFrame({
    'id': submission['id'],
    'prediction': y_pred.ravel()
})

submission.rename(columns={'prediction': 'sii'}, inplace=True)

submission.to_csv('submission.csv', index=False)

print("Submission file created successfully.")

# %%
submission
# Out:
#           id  prediction
# 0   00008ff9         2.0
# 1   000fd460         0.0
# 2   00105258         0.0
# 3   00115b9f         1.0
# 4   0016bb22         2.0
# 5   001f3379         1.0
# 6   0038ba98         0.0
# 7   0068a485         0.0
# 8   0069fbed         2.0
# 9   0083e397         2.0
# 10  0087dd65         0.0
# 11  00abe655         0.0
# 12  00ae59c9         1.0
# 13  00af6387         1.0
# 14  00bd4359         0.0
# 15  00c0cd71         2.0
# 16  00d56d4b         0.0
# 17  00d9913d         0.0
# 18  00e6167c         0.0
# 19  00ebc35d         1.0
